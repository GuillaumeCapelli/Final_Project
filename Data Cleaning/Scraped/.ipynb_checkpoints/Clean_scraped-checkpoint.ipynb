# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\guillaume capelli\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\guillaume capelli\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\guillaume capelli\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    ---------------------------------------- 151.4/151.4 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from collections import Counter
import re
import os
from wordcloud import WordCloud
import pandas as pd
from sqlalchemy import create_engine 
import pymysql.cursors

# %%
# Set the working directory
os.chdir(r'C:\Users\Guillaume\Desktop\Ironhack_189\Final_Project')

# Load the data
file_path = r'Dataset\Scraped_df\scraped_df.csv'
data = pd.read_csv(file_path)
data
# Out:
#                   username                                            comment  \
# 0            @jackjolly789  I'm not from the US but I sure as hell know no...
# 1             @DenverEight  I remember in Captain Planet, Mati’s power of ...
# 2               @jhartmggc  It’s tragic how this all unfolded. Unfortunate...
# 3         @datofficial6062  We dont need his "help to understand what we'r...
# 4            @panthercub10  You know it odd but the more this happens the ...
# ...                    ...                                                ...
# 2233     @claudiabotto3048                                              Trump
# 2234  @MichelSantana-xg5qi                      Trump and your beautiful lie.
# 2235           @slifer0081  As much as I hate trump and love migrants I ha...
# 2236           @george4821                       Trump was the rude one here.
# 2237      @billbarbosa4373            You should be ashame  of yourself trump
#
#                date  likes
# 0       3 years ago    160
# 1       3 years ago      0
# 2       3 years ago      0
# 3       3 years ago    289
# 4       3 years ago      1
# ...             ...    ...
# 2233  10 months ago      0
# 2234   5 months ago      0
# 2235   2 months ago      0
# 2236   3 months ago      0
# 2237  11 months ago      0
#
# [2238 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   username  2233 non-null   object
#  1   comment   2217 non-null   object
#  2   date      2238 non-null   object
#  3   likes     2238 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 70.1+ KB

# %%
data['date'].value_counts()
# Out:
# 3 years ago      1218
# 1 year ago        390
# 2 years ago       150
# 11 months ago      97
# 4 years ago        70
# 1 months ago       52
# 2 months ago       41
# 4 months ago       28
# 6 months ago       26
# 8 months ago       26
# 3 months ago       21
# 5 months ago       21
# 10 months ago      18
# 7 months ago       17
# 9 months ago       14
# 2 weeks agos       10
# 5 days agos         8
# 3 weeks agos        7
# 7 days agos         5
# 12 days agos        4
# 4 days agos         3
# 9 days agos         3
# 6 days agos         2
# 4 weeks agos        1
# 8 days agos         1
# 20 hours agos       1
# 14 hours agos       1
# 11 days agos        1
# 2 days agos         1
# 10 days agos        1
# Name: date, dtype: int64

# %%
# Define a function to convert relative dates into approximate absolute datetime objects
def approximate_date(relative_date_string, reference_date):
    """
    This function converts a relative date into an approximate absolute date.
    :param relative_date_string: A string indicating the relative date (e.g., '3 years ago').
    :param reference_date: The date to which the relative date refers.
    :return: An approximate absolute datetime object.
    """
    number, time_unit = re.match(r'(\d+)\s(\w+)', relative_date_string).groups()
    number = int(number)
    if 'year' in time_unit:
        return reference_date - timedelta(days=365 * number)
    elif 'month' in time_unit:
type: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# username             5
# comment             21
# date                 0
# likes                0
# approximate_date     0
# dtype: int64

# %%
data.dropna(subset=['username', 'comment'], inplace=True)

# %%
data['likes'].describe()
# Out:
# count    2212.000000
# mean       17.489602
# std        76.626151
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         3.000000
# max       980.000000
# Name: likes, dtype: float64

# %%
# Plotting the distribution of likes
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
data['likes'].hist(ax=ax, bins=50, edgecolor='black')
ax.set_title('Distribution of Likes')
ax.set_xlabel('Likes')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data
# Out:
#                   username                                            comment  \
# 0            @jackjolly789  I'm not from the US but I sure as hell know no...
# 1             @DenverEight  I remember in Captain Planet, Mati’s power of ...
# 2               @jhartmggc  It’s tragic how this all unfolded. Unfortunate...
# 3         @datofficial6062  We dont need his "help to understand what we'r...
# 4            @panthercub10  You know it odd but the more this happens the ...
# ...                    ...                                                ...
# 2233     @claudiabotto3048                                              Trump
# 2234  @MichelSantana-xg5qi                      Trump and your beautiful lie.
# 2235           @slifer0081  As much as I hate trump and love migrants I ha...
# 2236           @george4821                       Trump was the rude one here.
# 2237      @billbarbosa4373            You should be ashame  of yourself trump
#
#                date  likes           approximate_date
# 0       3 years ago    160 2020-11-13 10:40:59.345294
# 1       3 years ago      0 2020-11-13 10:40:59.345294
# 2       3 years ago      0 2020-11-13 10:40:59.345294
# 3       3 years ago    289 2020-11-13 10:40:59.345294
# 4       3 years ago      1 2020-11-13 10:40:59.345294
# ...             ...    ...                        ...
# 2233  10 months ago      0 2023-01-17 10:40:59.345294
# 2234   5 months ago      0 2023-06-16 10:40:59.345294
# 2235   2 months ago      0 2023-09-14 10:40:59.345294
# 2236   3 months ago      0 2023-08-15 10:40:59.345294
# 2237  11 months ago      0 2022-12-18 10:40:59.345294
#
# [2212 rows x 5 columns]

# %%
data['comment_length'] = data['comment'].apply(len)
data
# Out:
#                   username                                            comment  \
# 0            @jackjolly789  I'm not from the US but I sure as hell know no...
# 1             @DenverEight  I remember in Captain Planet, Mati’s power of ...
# 2               @jhartmggc  It’s tragic how this all unfolded. Unfortunate...
# 3         @datofficial6062  We dont need his "help to understand what we'r...
# 4            @panthercub10  You know it odd but the more this happens the ...
# ...                    ...                                                ...
# 2233     @claudiabotto3048                                              Trump
# 2234  @MichelSantana-xg5qi                      Trump and your beautiful lie.
# 2235           @slifer0081  As much as I hate trump and love migrants I ha...
# 2236           @george4821                       Trump was the rude one here.
# 2237      @billbarbosa4373            You should be ashame  of yourself trump
#
#                date  likes           approximate_date  comment_length
# 0       3 years ago    160 2020-11-13 10:40:59.345294             101
# 1       3 years ago      0 2020-11-13 10:40:59.345294             313
# 2       3 years ago      0 2020-11-13 10:40:59.345294             316
# 3       3 years ago    289 2020-11-13 10:40:59.345294             131
# 4       3 years ago      1 2020-11-13 10:40:59.345294             127
# ...             ...    ...                        ...             ...
# 2233  10 months ago      0 2023-01-17 10:40:59.345294               5
# 2234   5 months ago      0 2023-06-16 10:40:59.345294              29
# 2235   2 months ago      0 2023-09-14 10:40:59.345294             115
# 2236   3 months ago      0 2023-08-15 10:40:59.345294              28
# 2237  11 months ago      0 2022-12-18 10:40:59.345294              39
#
# [2212 rows x 6 columns]

# %%
# Rename 'likes' column to 'like' and remove the original 'date' column
data.rename(columns={'likes': 'like'}, inplace=True)
data.drop(columns='date', inplace=True) # Removing the original 'date' column

# %%
data.rename(columns={'approximate_date': 'date'}, inplace=True)
data
# Out:
#                   username                                            comment  \
# 0            @jackjolly789  I'm not from the US but I sure as hell know no...
# 1             @DenverEight  I remember in Captain Planet, Mati’s power of ...
# 2               @jhartmggc  It’s tragic how this all unfolded. Unfortunate...
# 3         @datofficial6062  We dont need his "help to understand what we'r...
# 4            @panthercub10  You know it odd but the more this happens the ...
# ...                    ...                                                ...
# 2233     @claudiabotto3048                                              Trump
# 2234  @MichelSantana-xg5qi                      Trump and your beautiful lie.
# 2235           @slifer0081  As much as I hate trump and love migrants I ha...
# 2236           @george4821                       Trump was the rude one here.
# 2237      @billbarbosa4373            You should be ashame  of yourself trump
#
#       like                       date  comment_length
# 0      160 2020-11-13 10:40:59.345294             101
# 1        0 2020-11-13 10:40:59.345294             313
# 2        0 2020-11-13 10:40:59.345294             316
# 3      289 2020-11-13 10:40:59.345294             131
# 4        1 2020-11-13 10:40:59.345294             127
# ...    ...                        ...             ...
# 2233     0 2023-01-17 10:40:59.345294               5
# 2234     0 2023-06-16 10:40:59.345294              29
# 2235     0 2023-09-14 10:40:59.345294             115
# 2236     0 2023-08-15 10:40:59.345294              28
# 2237     0 2022-12-18 10:40:59.345294              39
#
# [2212 rows x 5 columns]

# %%
# User Activity Analysis
user_activity = data['username'].value_counts().head(10)
user_activity
# Out:
# @joshuasJR            4
# @exactceamzis6525     4
# @arifcoco             4
# @bri9146              3
# @daeneydirusso4069    3
# @carmenkoening7728    3
# @sfl6307              3
# @gutz1981             3
# @zmaxpro5681          3
# @davidnichol6282      2
# Name: username, dtype: int64

# %%
# Plot User Activity
plt.figure(figsize=(10,5))
user_activity.plot(kind='bar', color='skyblue')
plt.title('Top 10 Active Users by Comment Count')
plt.xlabel('Username')
plt.ylabel('Number of Comments')
plt.show()

# %%
# Likes Over Time Analysis
likes_over_time = data.groupby(data['date'])['like'].sum()
likes_over_time
# Out:
# date
# 2019-11-14 10:40:59.345294     7927
# 2020-11-13 10:40:59.345294    21149
# 2021-11-13 10:40:59.345294     6052
# 2022-11-13 10:40:59.345294     2507
# 2022-12-18 10:40:59.345294      508
# 2023-01-17 10:40:59.345294       58
# 2023-02-16 10:40:59.345294        6
# 2023-03-18 10:40:59.345294       41
# 2023-04-17 10:40:59.345294       35
# 2023-05-17 10:40:59.345294      295
# 2023-06-16 10:40:59.345294       11
# 2023-07-16 10:40:59.345294       28
# 2023-08-15 10:40:59.345294       26
# 2023-09-14 10:40:59.345294       12
# 2023-10-14 10:40:59.345294       21
# 2023-11-01 10:40:59.345294        2
# 2023-11-02 10:40:59.345294        0
# 2023-11-03 10:40:59.345294        1
# 2023-11-04 10:40:59.345294        0
# 2023-11-05 10:40:59.345294        0
# 2023-11-06 10:40:59.345294        2
# 2023-11-07 10:40:59.345294        0
# 2023-11-08 10:40:59.345294        1
# 2023-11-09 10:40:59.345294        0
# 2023-11-11 10:40:59.345294        0
# 2023-11-12 14:40:59.345294        0
# 2023-11-12 20:40:59.345294        0
# 2023-11-13 10:40:59.345294        5
# Name: like, dtype: int64

# %%
# Plot Likes Over Time
plt.figure(figsize=(10,5))
likes_over_time.plot(color='purple')
plt.title('Likes Over Time')
plt.xlabel('Date')
plt.ylabel('Total Likes')
plt.show()

# %%
# Remove the '@' from the username column
data['username'] = data['username'].str.replace('@', '')

# %%
data['comment'] = data['comment'].str.replace('[^\w\s]', '', regex=True)

# %%
pw = os.getenv('MySQL_password')

# %%
connection_string = 'mysql+pymysql://root:' + pw + '@localhost:3306/'
engine = create_engine(connection_string)

# %%
data.to_sql('scraped_comment',engine, 'comment_toxicity', if_exists='replace', index=False)
# Out:
# 2212

# %%
# Save the cleaned and renamed DataFrame to a CSV file
output_file_path = r'C:\Users\Guillaume\Desktop\Ironhack_189\Final_Project\Data Cleaning\Scraped\cleaned_scraped_comments.csv'

# Save the cleaned and renamed DataFrame to a CSV file
data.to_csv(output_file_path, index=False, encoding='utf-8')

# %%
data
# Out:
#                  username                                            comment  \
# 0            jackjolly789  Im not from the US but I sure as hell know not...
# 1             DenverEight  I remember in Captain Planet Matis power of he...
# 2               jhartmggc  Its tragic how this all unfolded Unfortunately...
# 3         datofficial6062  We dont need his help to understand what were ...
# 4            panthercub10  You know it odd but the more this happens the ...
# ...                   ...                                                ...
# 2233     claudiabotto3048                                              Trump
# 2234  MichelSantana-xg5qi                       Trump and your beautiful lie
# 2235           slifer0081  As much as I hate trump and love migrants I ha...
# 2236           george4821                        Trump was the rude one here
# 2237      billbarbosa4373            You should be ashame  of yourself trump
#
#       like                       date  comment_length
# 0      160 2020-11-13 10:40:59.345294             101
# 1        0 2020-11-13 10:40:59.345294             313
# 2        0 2020-11-13 10:40:59.345294             316
# 3      289 2020-11-13 10:40:59.345294             131
# 4        1 2020-11-13 10:40:59.345294             127
# ...    ...                        ...             ...
# 2233     0 2023-01-17 10:40:59.345294               5
# 2234     0 2023-06-16 10:40:59.345294              29
# 2235     0 2023-09-14 10:40:59.345294             115
# 2236     0 2023-08-15 10:40:59.345294              28
# 2237     0 2022-12-18 10:40:59.345294              39
#
# [2212 rows x 5 columns]
